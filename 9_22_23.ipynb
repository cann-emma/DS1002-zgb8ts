# %% [markdown]
# <a href="https://colab.research.google.com/github/Cann-Emma/DS1002-zgb8ts/blob/main/9_22_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Loading packages
from io import IncrementalNewlineDecoder
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# importing dataframe
mockdat= pd.read_csv("MOCK_DATA.csv")
mockdat.info()
mockdat.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   Age         1000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 47.0+ KB
#                 id          Age
# count  1000.000000  1000.000000
# mean    500.500000    50.092000
# std     288.819436    28.961566
# min       1.000000     1.000000
# 25%     250.750000    24.000000
# 50%     500.500000    51.000000
# 75%     750.250000    75.000000
# max    1000.000000   100.000000

# %%
mockdat.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# first 5 observations in df
mockdat.head()
# Out:
#    id first_name  last_name                      email       gender  Age
# 0   1   Melantha      Barti        mbarti0@twitter.com     Bigender   13
# 1   2       Zena     Othick       zothick1@mozilla.org       Female   38
# 2   3      Raviv     Kopman        rkopman2@flickr.com         Male   39
# 3   4     Dulcea  Leschelle  dleschelle3@angelfire.com       Female   53
# 4   5      Maggy    Dorkens        mdorkens4@unblog.fr  Genderfluid   49

# %%
# getting some basic stats
mockdat.describe()
# Out:
#                 id          Age
# count  1000.000000  1000.000000
# mean    500.500000    50.092000
# std     288.819436    28.961566
# min       1.000000     1.000000
# 25%     250.750000    24.000000
# 50%     500.500000    51.000000
# 75%     750.250000    75.000000
# max    1000.000000   100.000000

# %%
# last 5 objects of df
mockdat.tail()
# Out:
#        id first_name   last_name                             email  \
# 995   996       Rafi   Callendar            rcallendarrn@cisco.com
# 996   997    Coletta  Silbermann  csilbermannro@chicagotribune.com
# 997   998       Cleo        Grog                cgrogrp@usnews.com
# 998   999     Roanna      Rhymes          rrhymesrq@whitehouse.gov
# 999  1000      Patty       Ezele       pezelerr@barnesandnoble.com
#
#          gender  Age
# 995        Male   45
# 996      Female   72
# 997      Female   33
# 998      Female   62
# 999  Polygender   96

# %%
# Subsetting dataframes, loc function + brackets
mockdat.loc[0]
# Out:
# id                              1
# first_name               Melantha
# last_name                   Barti
# email         mbarti0@twitter.com
# gender                   Bigender
# Age                            13
# Name: 0, dtype: object

# %%
# What columns or fields are in my df
mockdat.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'Age'], dtype='object')

# %%
mockdat.dtypes
# Out:
# id             int64
# first_name    object
# last_name     object
# email         object
# gender        object
# Age            int64
# dtype: object

# %%
# Changing column names using key:value
mockdat= mockdat.rename(columns= {"first_name":"fname", "last_name": "lname"})
mockdat.head()
# Out:
#    id     fname      lname                      email       gender  Age
# 0   1  Melantha      Barti        mbarti0@twitter.com     Bigender   13
# 1   2      Zena     Othick       zothick1@mozilla.org       Female   38
# 2   3     Raviv     Kopman        rkopman2@flickr.com         Male   39
# 3   4    Dulcea  Leschelle  dleschelle3@angelfire.com       Female   53
# 4   5     Maggy    Dorkens        mdorkens4@unblog.fr  Genderfluid   49

# %%
pd.value_counts(mockdat['gender']).plot.bar()
# Out:
# <Axes: >

# %%
mockdat.groupby(["gender"])["Age"].mean()
# Out:
# gender
# Agender        50.636364
# Bigender       41.615385
# Female         50.072340
# Genderfluid    48.714286
# Genderqueer    49.727273
# Male           49.907029
# Non-binary     57.739130
# Polygender     52.588235
# Name: Age, dtype: float64
