# %% [markdown]
# <a href="https://colab.research.google.com/github/Cann-Emma/DS1002-zgb8ts/blob/main/Testing_Transformations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
schools= pd.read_csv("schools.csv")

# %%
schools.shape
# Out:
# (375, 7)

# %%
schools.info
# Out:
# <bound method DataFrame.info of                                            school_name    borough  \
# 0    New Explorations into Science, Technology and ...  Manhattan
# 1                                 Essex Street Academy  Manhattan
# 2                         Lower Manhattan Arts Academy  Manhattan
# 3      High School for Dual Language and Asian Studies  Manhattan
# 4        Henry Street School for International Studies  Manhattan
# ..                                                 ...        ...
# 370  Queens High School for Information, Research, ...     Queens
# 371  Rockaway Park High School for Environmental Su...     Queens
# 372                   Channel View School for Research     Queens
# 373                    Rockaway Collegiate High School     Queens
# 374                                  Scholars' Academy     Queens
#
#     building_code  average_math  average_reading  average_writing  \
# 0            M022           657              601              601
# ...

# %%
schools.var()
# Out:
# <ipython-input-12-111ad28a75f0>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   schools.var()
# average_math        5177.143914
# average_reading     3829.266695
# average_writing     4166.521683
# percent_tested       351.473789
# total SAT          37988.459180
# dtype: float64

# %%
schools['total SAT']= schools['average_math']+ schools['average_reading']+ schools['average_writing']
schools
# Out:
#                                            school_name    borough  \
# 0    New Explorations into Science, Technology and ...  Manhattan
# 1                                 Essex Street Academy  Manhattan
# 2                         Lower Manhattan Arts Academy  Manhattan
# 3      High School for Dual Language and Asian Studies  Manhattan
# 4        Henry Street School for International Studies  Manhattan
# ..                                                 ...        ...
# 370  Queens High School for Information, Research, ...     Queens
# 371  Rockaway Park High School for Environmental Su...     Queens
# 372                   Channel View School for Research     Queens
# 373                    Rockaway Collegiate High School     Queens
# 374                                  Scholars' Academy     Queens
#
#     building_code  average_math  average_reading  average_writing  \
# 0            M022           657              601              601
# ...

# %%
boxcox()

# %%
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,2)
total_score_boxcox= schools['total SAT']
plt.figure()
sns.distplot(total_score_boxcox, label= "No Transformation", ax= ax[0], kde= True)

sns.distplot(total_score_log, label = "Log Transformation", color ="green", ax= ax[1])
fig.legend(loc= "upper right")
fig.set_figheight(5)
fig.set_figwidth(10)
fig.show()
# Out:
# <ipython-input-66-6f00f842c86c>:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(total_score_boxcox, label= "No Transformation", ax= ax[0], kde= True)
# <ipython-input-66-6f00f842c86c>:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
total_score_log= stats.boxcox(total_score_boxcox, lmbda=0)
total_score_log
# Out:
# array([7.52779399, 7.08422642, 7.13966034, 7.33236921, 7.08757371,
#        7.55695057, 7.06047637, 7.12689081, 7.04228617, 7.04664728,
#        7.16394668, 7.19067603, 7.1623975 , 6.95559261, 7.37274637,
#        7.21523998, 7.19067603, 7.11882625, 7.44073371, 7.13489085,
#        7.21376831, 7.07157336, 7.19067603, 7.40792432, 7.37086017,
#        7.32052696, 7.43838353, 7.06731985, 7.10332206, 7.05444966,
#        7.17165682, 7.38523092, 7.13648321, 7.33693691, 6.91274282,
#        7.04490512, 7.04925484, 6.99668149, 7.17625453, 7.1428274 ,
#        7.22037384, 7.23561914, 7.01750614, 7.16394668, 7.15773548,
#        7.54380287, 7.04228617, 7.09589322, 7.47533924, 7.48493028,
#        7.13489085, 7.40671073, 7.1180162 , 7.04053639, 7.29979737,
#        7.11151212, 7.068172  , 7.04490512, 7.43248381, 6.97634807,
#        7.06133437, 7.03438793, 7.23705903, 7.16780918, 7.25488481,
#        7.3498737 , 7.17088848, 7.08673793, 7.54380287, 7.21450441,
# ...

# %%
plt.figure()
sns.distplot(total_score_log, label = "Log Transformation", color ="green")
plt.legend(loc= "upper right")
plt.show()
# Out:
# <ipython-input-49-a7b972a87590>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(total_score_log, label = "Log", color ="green")

# %%
fig, ax = plt.subplots(1,2)
sns.distplot(total_score_boxcox, label= "No Transformation", ax= ax[0], kde= True)
sns.distplot(total_score_sqrt, label= "Square Root Transformation", color= "red", ax= ax[1])
fig.legend(loc= "upper right")
fig.set_figheight(5)
fig.set_figwidth(10)
fig.show()
# Out:
# <ipython-input-67-8d85cb0dc542>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(total_score_boxcox, label= "No Transformation", ax= ax[0], kde= True)
# <ipython-input-67-8d85cb0dc542>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
total_score_sqrt= stats.boxcox(total_score_boxcox, lmbda=0.5)

# %%
total_score_inv= stats.boxcox(total_score_boxcox, lmbda=-1)


fig, ax = plt.subplots(1,2)
sns.distplot(total_score_boxcox, label= "No Transformation", ax= ax[0])
sns.distplot(total_score_inv,label= "Inverse Transformation", color= "orange", ax= ax[1])
fig.legend(loc= "upper right")
fig.set_figheight(5)
fig.set_figwidth(10)
fig.show()
# Out:
# <ipython-input-68-de38742a99bd>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(total_score_boxcox, label= "No Transformation", ax= ax[0])
# <ipython-input-68-de38742a99bd>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...
